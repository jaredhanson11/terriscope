# %%
import geopandas as gpd

# Load the zip code geography data
gdf = gpd.read_file('../api/src/migrations/data/20251228-us_zcta_topo.json')

print(f"Total zip codes: {len(gdf)}")
print(f"\nColumns: {list(gdf.columns)}")
print(f"\nFirst few rows:")
gdf.head()
